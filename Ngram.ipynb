# %%
import nltk
from nltk.util import ngrams
from collections import Counter
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
sentences = [
    "I love programming."
    "I love learning new things."
    "Programming is fun."]
tokenized = [nltk.word_tokenize(s.lower()) for s in sentences]
def calculate_ngram(sentence, n):
  tokens = [token for s in sentences for token in s]
  n_grams = list(ngrams(tokens, n))
  ngram_freq = Counter(n_grams)
  n_1_grams = list(ngrams(tokens, n-1))
  n_1_gram_freq = Counter(n_1_grams)
  ngram_probabilities = {}
  for ngram, count in ngram_freq.items():
    prefix = ngram[:-1]
    prefix_count = n_1_gram_freq[prefix]
    prob = count / prefix_count if prefix_count > 0 else 0
    ngram_probabilities[ngram] = prob
  return ngram_probabilities
#Function to display probabilities ina readable format
def display_ngram(prob, n):
  print(f"\n{n}-Gram Probabilities:")
  for ngram, prob in prob.items():
    print(f" P({ngram}) = {prob:.4f}")
#calculate and display probabilities for unigrams, bigrams, and trigrams
for n in[1,2,3]:
  probabilities = calculate_ngram(tokenized, n)
  display_ngram(probabilities, n)
# Out:
# 1-Gram Probabilities:
#  P(('I',)) = 0.0303
#  P((' ',)) = 0.1212
#  P(('l',)) = 0.0455
#  P(('o',)) = 0.0606
#  P(('v',)) = 0.0303
#  P(('e',)) = 0.0606
#  P(('p',)) = 0.0152
#  P(('r',)) = 0.0758
#  P(('g',)) = 0.0909
#  P(('a',)) = 0.0455
#  P(('m',)) = 0.0606
#  P(('i',)) = 0.0758
#  P(('n',)) = 0.1061
#  P(('.',)) = 0.0455
#  P(('w',)) = 0.0152
#  P(('t',)) = 0.0152
#  P(('h',)) = 0.0152
#  P(('s',)) = 0.0303
#  P(('P',)) = 0.0152
#  P(('f',)) = 0.0152
#  P(('u',)) = 0.0152
#
# 2-Gram Probabilities:
#  P(('I', ' ')) = 1.0000
#  P((' ', 'l')) = 0.3750
#  P(('l', 'o')) = 0.6667
#  P(('o', 'v')) = 0.5000
#  P(('v', 'e')) = 1.0000
#  P(('e', ' ')) = 0.5000
#  P((' ', 'p')) = 0.1250
#  P(('p', 'r')) = 1.0000
#  P(('r', 'o')) = 0.4000
#  P(('o', 'g')) = 0.5000
#  P(('g', 'r')) = 0.3333
#  P(('r', 'a')) = 0.4000
#  P(('a', 'm')) = 0.6667
#  P(('m', 'm')) = 0.5000
#  P(('m', 'i')) = 0.5000
#  P(('i', 'n')) = 0.8000
#  P(('n', 'g')) = 0.5714
#  P(('g', '.')) = 0.1667
#  P(('.', 'I')) = 0.3333
#  P(('l', 'e')) = 0.3333
#  P(('e', 'a')) = 0.2500
#  P(('a', 'r')) = 0.3333
#  P(('r', 'n')) = 0.2000
#  P(('n', 'i')) = 0.1429
#  P(('g', ' ')) = 0.3333
#  P((' ', 'n')) = 0.1250
#  P(('n', 'e')) = 0.1429
#  P(('e', 'w')) = 0.2500
#  P(('w', ' ')) = 1.0000
#  P((' ', 't')) = 0.1250
#  P(('t', 'h')) = 1.0000
#  P(('h', 'i')) = 1.0000
#  P(('g', 's')) = 0.1667
#  P(('s', '.')) = 0.5000
#  P(('.', 'P')) = 0.3333
#  P(('P', 'r')) = 1.0000
#  P((' ', 'i')) = 0.1250
#  P(('i', 's')) = 0.2000
#  P(('s', ' ')) = 0.5000
#  P((' ', 'f')) = 0.1250
#  P(('f', 'u')) = 1.0000
#  P(('u', 'n')) = 1.0000
#  P(('n', '.')) = 0.1429
#
# 3-Gram Probabilities:
#  P(('I', ' ', 'l')) = 1.0000
#  P((' ', 'l', 'o')) = 0.6667
#  P(('l', 'o', 'v')) = 1.0000
#  P(('o', 'v', 'e')) = 1.0000
#  P(('v', 'e', ' ')) = 1.0000
#  P(('e', ' ', 'p')) = 0.5000
#  P((' ', 'p', 'r')) = 1.0000
#  P(('p', 'r', 'o')) = 1.0000
#  P(('r', 'o', 'g')) = 1.0000
#  P(('o', 'g', 'r')) = 1.0000
#  P(('g', 'r', 'a')) = 1.0000
#  P(('r', 'a', 'm')) = 1.0000
#  P(('a', 'm', 'm')) = 1.0000
#  P(('m', 'm', 'i')) = 1.0000
#  P(('m', 'i', 'n')) = 1.0000
#  P(('i', 'n', 'g')) = 1.0000
#  P(('n', 'g', '.')) = 0.2500
#  P(('g', '.', 'I')) = 1.0000
#  P(('.', 'I', ' ')) = 1.0000
#  P(('e', ' ', 'l')) = 0.5000
#  P((' ', 'l', 'e')) = 0.3333
#  P(('l', 'e', 'a')) = 1.0000
#  P(('e', 'a', 'r')) = 1.0000
#  P(('a', 'r', 'n')) = 1.0000
#  P(('r', 'n', 'i')) = 1.0000
#  P(('n', 'i', 'n')) = 1.0000
#  P(('n', 'g', ' ')) = 0.5000
#  P(('g', ' ', 'n')) = 0.5000
#  P((' ', 'n', 'e')) = 1.0000
#  P(('n', 'e', 'w')) = 1.0000
#  P(('e', 'w', ' ')) = 1.0000
#  P(('w', ' ', 't')) = 1.0000
#  P((' ', 't', 'h')) = 1.0000
#  P(('t', 'h', 'i')) = 1.0000
#  P(('h', 'i', 'n')) = 1.0000
#  P(('n', 'g', 's')) = 0.2500
#  P(('g', 's', '.')) = 1.0000
#  P(('s', '.', 'P')) = 1.0000
#  P(('.', 'P', 'r')) = 1.0000
#  P(('P', 'r', 'o')) = 1.0000
#  P(('g', ' ', 'i')) = 0.5000
#  P((' ', 'i', 's')) = 1.0000
#  P(('i', 's', ' ')) = 1.0000
#  P(('s', ' ', 'f')) = 1.0000
#  P((' ', 'f', 'u')) = 1.0000
#  P(('f', 'u', 'n')) = 1.0000
#  P(('u', 'n', '.')) = 1.0000
