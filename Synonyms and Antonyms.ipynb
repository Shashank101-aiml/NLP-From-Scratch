# %% [markdown]
# <a href="https://colab.research.google.com/github/Shashank101-aiml/NLP-From-Scratch/blob/main/Synonyms%20and%20Antonyms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.corpus import wordnet

# %%
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
def get_syn_ant(word):
  syno = set()
  anto = set()
  for s in wordnet.synsets(word):
    for lemma in s.lemmas():
      syno.add(lemma.name())
      if lemma.antonyms():
        anto.add(lemma.antonyms()[0].name())
  return syno, anto

# %%
word = 'active'
syno, anto = get_syn_ant(word)
print(f'Synonyms of {word} : {syno}')
print(f'Antonyms of {word} : {anto}')
# Out:
# Synonyms of active : {'combat-ready', 'alive', 'participating', 'active', 'active_voice', 'active_agent', 'fighting', 'dynamic'}
# Antonyms of active : {'passive_voice', 'dormant', 'passive', 'extinct', 'quiet', 'inactive', 'stative'}
